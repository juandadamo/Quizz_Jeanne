# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
from IPython.display import Latex, Image,display,clear_output
from ipywidgets import interact, interact_manual,interactive,widgets,Layout
import ipyplot

# %%
titulo1 = 'cual de estas series o películas prefieres?'
opciones1 = ['Obvio que Naruto','Amo a One piece',
             'Los jovenes titanes!','Gravity Falls','Avengers']
#(las personas que digan esto tienen muy buen gusto)
#np.vstack(opciones2,valores)
preg1 = widgets.RadioButtons( options=opciones1)
raiz1 = "imagenes/pelis/"
lista_imagenes = np.sort( (glob.glob (raiz1+'*.jpg')))
images_array = []
for i in range(len(lista_imagenes)):
    images_array = plt.imread(lista_imagenes[i])
images_array = np.asarray(images_array)

# %%
display(Latex(titulo1))
ipyplot.plot_images(lista_imagenes, max_images=len(lista_imagenes), img_width=150,custom_texts=opciones1);
preg1
# Out:
# cual de estas series o películas prefieres?
#     <style>
#         #ipyplot-html-viewer-toggle-nNLj4Edn6Lucsiqdw2Ytfg {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nNLj4Edn6Lucsiqdw2Ytfg {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nNLj4Edn6Lucsiqdw2Ytfg {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nNLj4Edn6Lucsiqdw2Ytfg:checked ~ #ipyplot-html-viewer-textarea-nNLj4Edn6Lucsiqdw2Ytfg {
#             height: 200px;
#             display: block;
#         }
#
# ...

# %%
titulo2 = 'Que comida prefieres?'
opciones2 = ['Arroz (chino o japones)','Karee raisu (curry)','Milanesa con papas fritas','Asado','Couscous']
valores = [2,3,4,1,0]
#np.vstack(opciones2,valores)
preg2 = widgets.RadioButtons( options=opciones2)
raiz2 = "imagenes/comidas/"
lista_imagenes = np.sort( (glob.glob (raiz2+'*.jpg')))
images_array = []
for i in range(len(lista_imagenes)):
    images_array = plt.imread(lista_imagenes[i])
images_array = np.asarray(images_array)

# %%
display(Latex(titulo2)
ipyplot.plot_images(lista_imagenes, max_images=len(lista_imagenes), img_width=150,custom_texts=opciones2);
preg2
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZmgdtxXHXq2KxjiQLQDG7S {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZmgdtxXHXq2KxjiQLQDG7S {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZmgdtxXHXq2KxjiQLQDG7S {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZmgdtxXHXq2KxjiQLQDG7S:checked ~ #ipyplot-html-viewer-textarea-ZmgdtxXHXq2KxjiQLQDG7S {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZmgdtxXHXq2KxjiQLQDG7S:checked + #ipyplot-html-viewer-label-ZmgdtxXHXq2KxjiQLQDG7S:after {
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-cfbc7e8754ca> in <module>
# ----> 1 preg2
#
# NameError: name 'preg2' is not defined

# %%
titulo3 = 'Alguien que no conoces  te patea ¿que haces?'
opciones3 = ['Lo pateo,si el no es bueno conmigo ¿porque yo si?',
             'Le digo que mire por donde va.',
             'Le digo que por favor se disculpe y que ya no haga eso.',
             'Le digo que le dire  a la profesora.',
             'Primero me ubico en una distancia protegida como para que no me pueda patear, y luego le digo lo mismo que la tercera pregunta']
opciones3_val =  range(5)
#np.vstack(opciones2,valores)
preg3 = widgets.RadioButtons( options=opciones3_val)
raiz3 = "imagenes/patada/"
lista_imagenes = np.sort( (glob.glob (raiz3+'*.jpg')))
images_array = []
for i in range(len(lista_imagenes)):
    images_array = plt.imread(lista_imagenes[i])
images_array = np.asarray(images_array)

# %%
display(Latex(titulo3))
display(Image('imagenes/patada.jpg',width=100 ))
texto_opciones = [f'{i:.0f} '+opcion for i,opcion in enumerate(opciones3)]
for opcion in texto_opciones:
    display(Latex(opcion))
# Out:
# Alguien que no conoces  te patea ¿que haces?
# 0 Lo pateo,si el no es bueno conmigo ¿porque yo si?
# 1 Le digo que mire por donde va.
# 2 Le digo que por favor se disculpe y que ya no haga eso.
# 3 Le digo que le dire  a la profesora.
# 4 Primero me ubico en una distancia protegida como para que no me pueda patear, y luego le digo lo mismo que la tercera pregunta

# %%
preg3
# Out:
# RadioButtons(options=(0, 1, 2, 3, 4), value=0)

# %%
titulo4 = 'Que cosa mas prohibida has hecho?'
opciones4 = ['Beber una botella de leche directamente',
             'Cruce una calle de la cual no tenia permiso cruzar.',
             'Le pegue a alguien.',
             'Me burle de alguien por su aspecto',
             'Primero me ubico en una distancia protegida como para que no me pueda patear, y luego le digo lo mismo que la tercera pregunta']
opciones4_val =  range(5)
#np.vstack(opciones2,valores)
preg4 = widgets.RadioButtons( options=opciones3_val)
raiz4 = "imagenes/confidential/"
lista_imagenes = np.sort( (glob.glob (raiz3+'*.jpg')))
images_array = []
for i in range(len(lista_imagenes)):
    images_array = plt.imread(lista_imagenes[i])
images_array = np.asarray(images_array)

# %%
preg1.index, preg3.index
# Out:
# (3, 2)
